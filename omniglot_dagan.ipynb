# %% [markdown]
# Project code link: https://github.com/amurthy1/dagan_torch.git

# %%
import os
# !nvidia-smi -L
# Out:
# GPU 0: Tesla V100-SXM2-16GB (UUID: GPU-5eb4bcd0-b42d-9800-9fc3-9c77fb310eb4)

# %%
if "dagan_torch" not in os.getcwd():
    if "dagan_torch" not in os.listdir("."):
        os.system("git clone https://github.com/amurthy1/dagan_torch.git")
    os.chdir("dagan_torch")

if "omniglot_data.npy" not in os.listdir("datasets"):
    os.system("gdown --id 1_zEVEjABc34QztDH8oIPQv-xUMXc_alq --output datasets/omniglot_data.npy")

# %%
# Optional to save generator, checkpoint to your google drive
# Prevents data being erased if colab session disconnects
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %run train_dagan.py datasets/omniglot_data.npy /content/drive/MyDrive/2024-SemA/Generative-Deep-Learning/DAGAN-torch/final_omniglot_generator.pt --save_checkpoint_path /content/drive/MyDrive/2024-SemA/Generative-Deep-Learning/DAGAN-torch/omniglot_checkpoint.pt
# Out:
# Epoch 0
# Elapsed time: 0.02 minutes
#
# Iteration 0
# <PIL.Image.Image image mode=L size=336x28>
# <PIL.Image.Image image mode=L size=336x28>
# D: 0.0
# Raw D: 0.0
# GP: 0.0
# Gradient norm: 0.0
# Iteration 75
# <PIL.Image.Image image mode=L size=336x28>
# <PIL.Image.Image image mode=L size=336x28>
# D: -7.696770191192627
# Raw D: -9.343740582466125
# GP: 1.6469703912734985
# Gradient norm: 1.158592939376831
# G: 1.016804814338684
# Iteration 150
# <PIL.Image.Image image mode=L size=336x28>
# <PIL.Image.Image image mode=L size=336x28>
# D: -9.11435317993164
# Raw D: -9.622104406356812
# GP: 0.5077512264251709
# Gradient norm: 1.139657974243164
# G: -7.079258918762207
# Iteration 225
# <PIL.Image.Image image mode=L size=336x28>
# <PIL.Image.Image image mode=L size=336x28>
# D: -7.940311431884766
# Raw D: -8.854456067085266
# GP: 0.9141446352005005
# Gradient norm: 0.7264662981033325
# G: -3.2683496475219727
# Iteration 300
# <PIL.Image.Image image mode=L size=336x28>
# ...
